# %%
cd D:\\Arman\Dokkho Cohort 4 Course Materials\Data Analysis Project
# Out:
# D:\Arman\Dokkho Cohort 4 Course Materials\Data Analysis Project

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Batsman Summary

# %%
df = pd.read_csv('batsman_summary.csv')
df.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)    20
#
#    balls  4s  6s      SR out/not_out     match_id
# 0      6   0   0      50         out  T20I # 1823
# 1      9   1   0     100         out  T20I # 1823
# 2     12   1   2  166.66         out  T20I # 1823
# 3     24   2   0  108.33         out  T20I # 1823
# 4     24   0   0   83.33         out  T20I # 1823

# %%
columns_to_drop = ['match','battingPos','out/not_out','match_id']
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.head()
# Out:
#   teamInnings             batsmanName  runs  balls  4s  6s      SR
# 0     Namibia      Michael van Lingen     3      6   0   0      50
# 1     Namibia           Divan la Cock     9      9   1   0     100
# 2     Namibia  Jan Nicol Loftie-Eaton    20     12   1   2  166.66
# 3     Namibia           Stephan Baard    26     24   2   0  108.33
# 4     Namibia      Gerhard Erasmus(c)    20     24   0   0   83.33

# %%
new_column_names={'teamInnings':'Country','batsmanName':'Batsman','runs':'Runs','balls':'Balls','SR':'Strike_Rates'}
df.rename(columns=new_column_names,inplace=True)

# %%
df.head()
# Out:
#    Country                 Batsman  Runs  Balls  4s  6s Strike_Rates
# 0  Namibia      Michael van Lingen     3      6   0   0           50
# 1  Namibia           Divan la Cock     9      9   1   0          100
# 2  Namibia  Jan Nicol Loftie-Eaton    20     12   1   2       166.66
# 3  Namibia           Stephan Baard    26     24   2   0       108.33
# 4  Namibia      Gerhard Erasmus(c)    20     24   0   0        83.33

# %%
df.tail()
# Out:
#      Country           Batsman  Runs  Balls  4s  6s Strike_Rates
# 694  England         Phil Salt    10      9   2   0       111.11
# 695  England        Ben Stokes    52     49   5   1       106.12
# 696  England       Harry Brook    20     23   1   0        86.95
# 697  England         Moeen Ali    19     13   3   0       146.15
# 698  England  Liam Livingstone     1      1   0   0          100

# %%
df.isnull().sum()
# Out:
# Country         0
# Batsman         0
# Runs            0
# Balls           0
# 4s              0
# 6s              0
# Strike_Rates    0
# dtype: int64

# %%
df.shape
# Out:
# (699, 7)

# %%
columns = df.columns.tolist()
new_columns = columns[1:] + [columns[0]]
df = df[new_columns]

# %%
df.head()
# Out:
#                   Batsman  Runs  Balls  4s  6s Strike_Rates  Country
# 0      Michael van Lingen     3      6   0   0           50  Namibia
# 1           Divan la Cock     9      9   1   0          100  Namibia
# 2  Jan Nicol Loftie-Eaton    20     12   1   2       166.66  Namibia
# 3           Stephan Baard    26     24   2   0       108.33  Namibia
# 4      Gerhard Erasmus(c)    20     24   0   0        83.33  Namibia

# %%
df.tail()
# Out:
#               Batsman  Runs  Balls  4s  6s Strike_Rates  Country
# 694         Phil Salt    10      9   2   0       111.11  England
# 695        Ben Stokes    52     49   5   1       106.12  England
# 696       Harry Brook    20     23   1   0        86.95  England
# 697         Moeen Ali    19     13   3   0       146.15  England
# 698  Liam Livingstone     1      1   0   0          100  England

# %%
df.to_csv('new_batsman_summary.csv',index=False)

# %% [markdown]
# ### Bowler Summary

# %%
df1 = pd.read_csv('bowler_summary.csv')
df1.head()
# Out:
#                   match bowlingTeam                  bowlerName  overs  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana    4.0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera    4.0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan    4.0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne    4.0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva    4.0
#
#    maiden  runs  wickets  economy  0s  4s  6s  wides  noBalls     match_id
# 0       0    23        1     5.75   7   0   0      2        0  T20I # 1823
# 1       0    39        1     9.75   6   3   1      2        0  T20I # 1823
# 2       0    37        2     9.25   6   3   1      0        0  T20I # 1823
# 3       0    36        1     9.00   7   3   1      1        0  T20I # 1823
# 4       0    27        1     6.75   8   1   1      0        0  T20I # 1823

# %%
columns_drop = ['match','wides','noBalls','match_id']
df1.drop(columns=columns_drop,inplace=True)
df1.head()
# Out:
#   bowlingTeam                  bowlerName  overs  maiden  runs  wickets  \
# 0   Sri Lanka          Maheesh Theekshana    4.0       0    23        1
# 1   Sri Lanka         Dushmantha Chameera    4.0       0    39        1
# 2   Sri Lanka             Pramod Madushan    4.0       0    37        2
# 3   Sri Lanka         Chamika Karunaratne    4.0       0    36        1
# 4   Sri Lanka  Wanindu Hasaranga de Silva    4.0       0    27        1
#
#    economy  0s  4s  6s
# 0     5.75   7   0   0
# 1     9.75   6   3   1
# 2     9.25   6   3   1
# 3     9.00   7   3   1
# 4     6.75   8   1   1

# %%
new_columns_name = {'bowlingTeam':'Country','bowlerName':'Bowler','overs':'Overs','maiden':'Maiden','runs':'Runs','wickets':'Wickets','economy':'Economy'}
df1.rename(columns=new_columns_name,inplace=True)
df1.head()
# Out:
#      Country                      Bowler  Overs  Maiden  Runs  Wickets  \
# 0  Sri Lanka          Maheesh Theekshana    4.0       0    23        1
# 1  Sri Lanka         Dushmantha Chameera    4.0       0    39        1
# 2  Sri Lanka             Pramod Madushan    4.0       0    37        2
# 3  Sri Lanka         Chamika Karunaratne    4.0       0    36        1
# 4  Sri Lanka  Wanindu Hasaranga de Silva    4.0       0    27        1
#
#    Economy  0s  4s  6s
# 0     5.75   7   0   0
# 1     9.75   6   3   1
# 2     9.25   6   3   1
# 3     9.00   7   3   1
# 4     6.75   8   1   1

# %%
columns1 = df1.columns.tolist()
new_column1 = columns1[1:] + [columns1[0]]
df1 = df1[new_column1]
df1.head()
# Out:
#                        Bowler  Overs  Maiden  Runs  Wickets  Economy  0s  4s  \
# 0          Maheesh Theekshana    4.0       0    23        1     5.75   7   0
# 1         Dushmantha Chameera    4.0       0    39        1     9.75   6   3
# 2             Pramod Madushan    4.0       0    37        2     9.25   6   3
# 3         Chamika Karunaratne    4.0       0    36        1     9.00   7   3
# 4  Wanindu Hasaranga de Silva    4.0       0    27        1     6.75   8   1
#
#    6s    Country
# 0   0  Sri Lanka
# 1   1  Sri Lanka
# 2   1  Sri Lanka
# 3   1  Sri Lanka
# 4   1  Sri Lanka

# %%
df1.shape
# Out:
# (500, 10)

# %%
df1.isnull().sum()
# Out:
# Bowler     0
# Overs      0
# Maiden     0
# Runs       0
# Wickets    0
# Economy    0
# 0s         0
# 4s         0
# 6s         0
# Country    0
# dtype: int64

# %%
df1.to_csv('new_bowler_summary.csv',index=False)
